# %% [markdown]
# <a href="https://colab.research.google.com/github/s-a-g-n-i-k-a/C/blob/main/classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
################classification using logistic regression#################
#########import dataframes,liberaries and modules########################
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
####################reading the data frame###############################
df= pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.xlabel("age")
plt.ylabel("bought_insurance")
plt.scatter(df[["age"]], df.bought_insurance, color="red", marker=".")

# %%
#########################spliting the given data frame into train and test ##################################
df.shape
x_train, x_test,y_train, y_test=train_test_split(df[["age"]], df.bought_insurance,train_size=0.8, test_size=0.2)
x_train
# Out:
#     age
# 18   19
# 15   55
# 23   45
# 20   21
# 19   18
# 13   29
# 14   49
# 1    25
# 25   54
# 5    56
# 2    47
# 8    62
# 17   58
# 22   40
# 3    52
# 24   50
# 4    46
# 26   23
# 16   25
# 10   18
# 0    22

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0, 0, 1, 1])

# %%
################model accuracy###############################
model.score(x_test, y_test)
# Out:
# 0.8333333333333334
